# %% [markdown]
# # Deliverable 1: Generate 2000 cities

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | taltal
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | prachuap khiri khan
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | berasia
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | mount isa
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | northam
# Processing Record 15 of Set 1 | excelsior springs
# Processing Record 16 of Set 1 | tateyama
# Processing Record 17 of Set 1 | murmashi
# Processing Record 18 of Set 1 | fukue
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | kamina
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | nagireddipalle
# City not found. Skipping...
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | portland
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | middleton
# Processing Record 31 of Set 1 | camaqua
# Processing Record 32 of Set 1 | namatanai
# Processing Record 33 of Set 1 | eitorf
# Processing Record 34 of Set 1 | port blair
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | umm lajj
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | joshimath
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | dzhebariki-khaya
# Processing Record 44 of Set 1 | bani walid
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | praia
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | pimentel
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | tarakan
# Processing Record 9 of Set 2 | zyryanka
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | honningsvag
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | vostok
# Processing Record 17 of Set 2 | kokkola
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | riyadh
# Processing Record 20 of Set 2 | yumen
# Processing Record 21 of Set 2 | sicuani
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | balyaga
# Processing Record 25 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 2 | les cayes
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | san pedro
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | shimoda
# Processing Record 32 of Set 2 | sao jose da coroa grande
# Processing Record 33 of Set 2 | troitsko-pechorsk
# Processing Record 34 of Set 2 | matay
# Processing Record 35 of Set 2 | pangnirtung
# Processing Record 36 of Set 2 | watertown
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | kenai
# Processing Record 40 of Set 2 | yeppoon
# Processing Record 41 of Set 2 | dongning
# Processing Record 42 of Set 2 | quelimane
# Processing Record 43 of Set 2 | srednekolymsk
# Processing Record 44 of Set 2 | balabac
# Processing Record 45 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | pflugerville
# Processing Record 49 of Set 2 | progreso
# Processing Record 50 of Set 2 | najran
# Processing Record 1 of Set 3 | challapata
# Processing Record 2 of Set 3 | lakhimpur
# Processing Record 3 of Set 3 | qaqortoq
# Processing Record 4 of Set 3 | bam
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | springfield
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | donskoye
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | raudeberg
# Processing Record 15 of Set 3 | benton harbor
# Processing Record 16 of Set 3 | maningrida
# Processing Record 17 of Set 3 | walvis bay
# Processing Record 18 of Set 3 | potma
# City not found. Skipping...
# Processing Record 19 of Set 3 | manadhoo
# Processing Record 20 of Set 3 | tanete
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | youkounkoun
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | manokwari
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | antofagasta
# Processing Record 28 of Set 3 | laguna de perlas
# Processing Record 29 of Set 3 | meulaboh
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | malpe
# Processing Record 32 of Set 3 | tazovskiy
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | jinchang
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | khasan
# Processing Record 38 of Set 3 | kyzyl-suu
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | berkovica
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | camopi
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | muirkirk
# Processing Record 48 of Set 3 | nemuro
# Processing Record 49 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 3 | deputatskiy
# Processing Record 1 of Set 4 | vardo
# Processing Record 2 of Set 4 | karratha
# Processing Record 3 of Set 4 | vestmannaeyjar
# Processing Record 4 of Set 4 | akdepe
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | genhe
# Processing Record 7 of Set 4 | zabol
# Processing Record 8 of Set 4 | zyrardow
# Processing Record 9 of Set 4 | novo aripuana
# Processing Record 10 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | broken hill
# Processing Record 13 of Set 4 | aksu
# Processing Record 14 of Set 4 | butaritari
# Processing Record 15 of Set 4 | manggar
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | matagami
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | galle
# Processing Record 20 of Set 4 | lokosovo
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | kedrovka
# Processing Record 23 of Set 4 | mezen
# Processing Record 24 of Set 4 | rock sound
# Processing Record 25 of Set 4 | shimanovsk
# Processing Record 26 of Set 4 | ternate
# Processing Record 27 of Set 4 | requena
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | ulladulla
# Processing Record 30 of Set 4 | kimbe
# Processing Record 31 of Set 4 | buraydah
# Processing Record 32 of Set 4 | taoudenni
# Processing Record 33 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 4 | bani
# Processing Record 35 of Set 4 | paracatu
# Processing Record 36 of Set 4 | padilla
# Processing Record 37 of Set 4 | teguldet
# Processing Record 38 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | bjorkelangen
# Processing Record 41 of Set 4 | hongjiang
# Processing Record 42 of Set 4 | dong xoai
# Processing Record 43 of Set 4 | sioux lookout
# Processing Record 44 of Set 4 | ca mau
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | trincomalee
# Processing Record 47 of Set 4 | ormara
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | maniitsoq
# Processing Record 50 of Set 4 | urumqi
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 5 | carnarvon
# Processing Record 5 of Set 5 | robat karim
# Processing Record 6 of Set 5 | wellington
# Processing Record 7 of Set 5 | east london
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | lakselv
# Processing Record 10 of Set 5 | acari
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | thunder bay
# Processing Record 13 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | burnie
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | leshan
# Processing Record 18 of Set 5 | boyolangu
# Processing Record 19 of Set 5 | visby
# Processing Record 20 of Set 5 | berikulskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | jumla
# Processing Record 22 of Set 5 | bojkovice
# Processing Record 23 of Set 5 | north bend
# Processing Record 24 of Set 5 | gushikawa
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | impfondo
# Processing Record 27 of Set 5 | kargasok
# Processing Record 28 of Set 5 | tullahoma
# Processing Record 29 of Set 5 | sao joao da barra
# Processing Record 30 of Set 5 | bandarbeyla
# Processing Record 31 of Set 5 | lindsay
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | yerbogachen
# Processing Record 34 of Set 5 | chuy
# Processing Record 35 of Set 5 | kapaa
# Processing Record 36 of Set 5 | banjar
# Processing Record 37 of Set 5 | orlovskiy
# Processing Record 38 of Set 5 | manakara
# Processing Record 39 of Set 5 | barranca
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | slavsk
# Processing Record 42 of Set 5 | awbari
# Processing Record 43 of Set 5 | changde
# Processing Record 44 of Set 5 | santa rosa
# Processing Record 45 of Set 5 | sakmara
# Processing Record 46 of Set 5 | richards bay
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | varangaon
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | ballina
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | camana
# Processing Record 4 of Set 6 | koutsouras
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | cururupu
# Processing Record 8 of Set 6 | domna
# Processing Record 9 of Set 6 | hay river
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | san matias
# Processing Record 12 of Set 6 | smidovich
# Processing Record 13 of Set 6 | shenjiamen
# Processing Record 14 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 6 | ojinaga
# Processing Record 16 of Set 6 | bac lieu
# Processing Record 17 of Set 6 | srandakan
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | forssa
# Processing Record 20 of Set 6 | yabelo
# Processing Record 21 of Set 6 | singaraja
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | kungurtug
# Processing Record 24 of Set 6 | raton
# Processing Record 25 of Set 6 | kavos
# Processing Record 26 of Set 6 | miraflores
# Processing Record 27 of Set 6 | maceio
# Processing Record 28 of Set 6 | scarborough
# Processing Record 29 of Set 6 | havre-saint-pierre
# Processing Record 30 of Set 6 | pacific grove
# Processing Record 31 of Set 6 | ilanskiy
# Processing Record 32 of Set 6 | atar
# Processing Record 33 of Set 6 | phan thiet
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 36 of Set 6 | kangaatsiaq
# Processing Record 37 of Set 6 | curtea
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | port lincoln
# Processing Record 40 of Set 6 | chisec
# Processing Record 41 of Set 6 | aksha
# Processing Record 42 of Set 6 | maragogi
# Processing Record 43 of Set 6 | matamoros
# Processing Record 44 of Set 6 | krasnokholmskiy
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | oktyabrskiy
# Processing Record 47 of Set 6 | nazilli
# Processing Record 48 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 49 of Set 6 | mingyue
# Processing Record 50 of Set 6 | sokode
# Processing Record 1 of Set 7 | brae
# Processing Record 2 of Set 7 | egvekinot
# Processing Record 3 of Set 7 | yulara
# Processing Record 4 of Set 7 | dali
# Processing Record 5 of Set 7 | guasdualito
# Processing Record 6 of Set 7 | riobamba
# Processing Record 7 of Set 7 | tevaitoa
# Processing Record 8 of Set 7 | yaan
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | ndioum
# Processing Record 11 of Set 7 | hearst
# Processing Record 12 of Set 7 | udachnyy
# Processing Record 13 of Set 7 | maryville
# Processing Record 14 of Set 7 | mayo
# Processing Record 15 of Set 7 | kefalos
# Processing Record 16 of Set 7 | berlevag
# Processing Record 17 of Set 7 | shahrud
# Processing Record 18 of Set 7 | te anau
# Processing Record 19 of Set 7 | tahta
# Processing Record 20 of Set 7 | cairns
# Processing Record 21 of Set 7 | verkhnetulomskiy
# Processing Record 22 of Set 7 | ambilobe
# Processing Record 23 of Set 7 | monte alegre
# Processing Record 24 of Set 7 | necochea
# Processing Record 25 of Set 7 | anshun
# Processing Record 26 of Set 7 | sharjah
# Processing Record 27 of Set 7 | biak
# Processing Record 28 of Set 7 | sapouy
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | mahuva
# Processing Record 32 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 7 | boa vista
# Processing Record 34 of Set 7 | santa cruz
# Processing Record 35 of Set 7 | chhatapur
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | mitu
# Processing Record 38 of Set 7 | bulgan
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | straumen
# Processing Record 41 of Set 7 | koroni
# Processing Record 42 of Set 7 | saint george
# Processing Record 43 of Set 7 | port moresby
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | gat
# Processing Record 46 of Set 7 | savannah bight
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | kismayo
# Processing Record 50 of Set 7 | barcelos
# Processing Record 1 of Set 8 | padang
# Processing Record 2 of Set 8 | ornskoldsvik
# Processing Record 3 of Set 8 | marovoay
# Processing Record 4 of Set 8 | pangai
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 7 of Set 8 | griffith
# Processing Record 8 of Set 8 | yuzhno-sukhokumsk
# Processing Record 9 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 8 | mahebourg
# Processing Record 11 of Set 8 | stromness
# Processing Record 12 of Set 8 | poya
# Processing Record 13 of Set 8 | vaitape
# Processing Record 14 of Set 8 | yamada
# Processing Record 15 of Set 8 | almaznyy
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | calama
# Processing Record 18 of Set 8 | kaitangata
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | port-cartier
# Processing Record 21 of Set 8 | laguna
# Processing Record 22 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | kaeo
# Processing Record 24 of Set 8 | college
# Processing Record 25 of Set 8 | kulgam
# Processing Record 26 of Set 8 | gloversville
# Processing Record 27 of Set 8 | cao bang
# Processing Record 28 of Set 8 | saint anthony
# Processing Record 29 of Set 8 | chivay
# Processing Record 30 of Set 8 | tecoanapa
# Processing Record 31 of Set 8 | erzurum
# Processing Record 32 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 8 | kidal
# Processing Record 34 of Set 8 | hammerfest
# Processing Record 35 of Set 8 | antiguo morelos
# Processing Record 36 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 8 | ixtapa
# Processing Record 38 of Set 8 | capaci
# Processing Record 39 of Set 8 | huntington
# Processing Record 40 of Set 8 | tianpeng
# Processing Record 41 of Set 8 | chokurdakh
# Processing Record 42 of Set 8 | dudinka
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | tikhvin
# Processing Record 45 of Set 8 | san policarpo
# Processing Record 46 of Set 8 | rawson
# Processing Record 47 of Set 8 | vikhorevka
# Processing Record 48 of Set 8 | neropolis
# Processing Record 49 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 9 | acapulco
# Processing Record 2 of Set 9 | constitucion
# Processing Record 3 of Set 9 | itacoatiara
# Processing Record 4 of Set 9 | tura
# Processing Record 5 of Set 9 | port ellen
# City not found. Skipping...
# Processing Record 6 of Set 9 | inverell
# Processing Record 7 of Set 9 | lieto
# Processing Record 8 of Set 9 | morant bay
# Processing Record 9 of Set 9 | bulancak
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | marolambo
# Processing Record 12 of Set 9 | abonnema
# Processing Record 13 of Set 9 | praxedis guerrero
# Processing Record 14 of Set 9 | fairbanks
# Processing Record 15 of Set 9 | orcopampa
# Processing Record 16 of Set 9 | gilazi
# City not found. Skipping...
# Processing Record 17 of Set 9 | la ronge
# Processing Record 18 of Set 9 | sterling
# Processing Record 19 of Set 9 | chumikan
# Processing Record 20 of Set 9 | luba
# Processing Record 21 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 9 | naryan-mar
# Processing Record 23 of Set 9 | waipawa
# Processing Record 24 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 9 | karachi
# Processing Record 26 of Set 9 | kruisfontein
# Processing Record 27 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 9 | amahai
# Processing Record 29 of Set 9 | nantucket
# Processing Record 30 of Set 9 | canita
# Processing Record 31 of Set 9 | okato
# Processing Record 32 of Set 9 | krasnyy chikoy
# Processing Record 33 of Set 9 | cherepovets
# Processing Record 34 of Set 9 | amazar
# Processing Record 35 of Set 9 | jiaonan
# Processing Record 36 of Set 9 | katsuura
# Processing Record 37 of Set 9 | darab
# Processing Record 38 of Set 9 | imbituba
# Processing Record 39 of Set 9 | kedrovyy
# Processing Record 40 of Set 9 | palmer
# Processing Record 41 of Set 9 | aberdeen
# Processing Record 42 of Set 9 | alwar tirunagari
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | senno
# Processing Record 45 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | shaki
# Processing Record 48 of Set 9 | upington
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | kununurra
# Processing Record 1 of Set 10 | valenca
# Processing Record 2 of Set 10 | harper
# Processing Record 3 of Set 10 | bambanglipuro
# Processing Record 4 of Set 10 | zhigansk
# Processing Record 5 of Set 10 | guarapari
# Processing Record 6 of Set 10 | lufilufi
# Processing Record 7 of Set 10 | husavik
# Processing Record 8 of Set 10 | miramar
# Processing Record 9 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 10 of Set 10 | culfa
# Processing Record 11 of Set 10 | whitehaven
# Processing Record 12 of Set 10 | cuamba
# Processing Record 13 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | mamou
# Processing Record 15 of Set 10 | mahajanga
# Processing Record 16 of Set 10 | wagar
# Processing Record 17 of Set 10 | novodolinskiy
# Processing Record 18 of Set 10 | francisco beltrao
# Processing Record 19 of Set 10 | mitsamiouli
# Processing Record 20 of Set 10 | tuatapere
# Processing Record 21 of Set 10 | colon
# Processing Record 22 of Set 10 | ostersund
# Processing Record 23 of Set 10 | jiangyou
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | gandajika
# Processing Record 26 of Set 10 | montague
# Processing Record 27 of Set 10 | kloulklubed
# Processing Record 28 of Set 10 | port macquarie
# Processing Record 29 of Set 10 | laval
# Processing Record 30 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 31 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 34 of Set 10 | xingyi
# Processing Record 35 of Set 10 | lityn
# Processing Record 36 of Set 10 | skjervoy
# Processing Record 37 of Set 10 | ziarat
# Processing Record 38 of Set 10 | huarmey
# Processing Record 39 of Set 10 | irbit
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | alofi
# Processing Record 42 of Set 10 | rio gallegos
# Processing Record 43 of Set 10 | malanje
# Processing Record 44 of Set 10 | haines junction
# Processing Record 45 of Set 10 | huangcun
# Processing Record 46 of Set 10 | balgazyn
# Processing Record 47 of Set 10 | sakakah
# Processing Record 48 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 10 | kashi
# Processing Record 50 of Set 10 | semirom
# Processing Record 1 of Set 11 | mehran
# Processing Record 2 of Set 11 | louis trichardt
# Processing Record 3 of Set 11 | gore
# Processing Record 4 of Set 11 | trojes
# Processing Record 5 of Set 11 | jalu
# Processing Record 6 of Set 11 | khani
# Processing Record 7 of Set 11 | sabang
# Processing Record 8 of Set 11 | san cristobal
# Processing Record 9 of Set 11 | psebay
# Processing Record 10 of Set 11 | abu kamal
# Processing Record 11 of Set 11 | ormond beach
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | onguday
# Processing Record 14 of Set 11 | kishi
# Processing Record 15 of Set 11 | margate
# Processing Record 16 of Set 11 | gigmoto
# Processing Record 17 of Set 11 | high level
# Processing Record 18 of Set 11 | saldanha
# Processing Record 19 of Set 11 | carballo
# Processing Record 20 of Set 11 | arman
# Processing Record 21 of Set 11 | saint-francois
# Processing Record 22 of Set 11 | santiago tuxtla
# Processing Record 23 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 24 of Set 11 | hamilton
# Processing Record 25 of Set 11 | bardiyah
# Processing Record 26 of Set 11 | ygatimi
# Processing Record 27 of Set 11 | stary sacz
# Processing Record 28 of Set 11 | pyaozerskiy
# Processing Record 29 of Set 11 | altay
# Processing Record 30 of Set 11 | boa viagem
# Processing Record 31 of Set 11 | cartagena del chaira
# Processing Record 32 of Set 11 | sosnovo-ozerskoye
# Processing Record 33 of Set 11 | shaping
# Processing Record 34 of Set 11 | honiara
# Processing Record 35 of Set 11 | vicosa do ceara
# Processing Record 36 of Set 11 | porto da folha
# Processing Record 37 of Set 11 | lima
# Processing Record 38 of Set 11 | komsomolskiy
# Processing Record 39 of Set 11 | freetown
# Processing Record 40 of Set 11 | aklavik
# Processing Record 41 of Set 11 | barra dos coqueiros
# Processing Record 42 of Set 11 | deer lake
# Processing Record 43 of Set 11 | ambulu
# Processing Record 44 of Set 11 | auki
# Processing Record 45 of Set 11 | etchoropo
# Processing Record 46 of Set 11 | banda aceh
# Processing Record 47 of Set 11 | ostrovnoy
# Processing Record 48 of Set 11 | cianorte
# Processing Record 49 of Set 11 | willowmore
# Processing Record 50 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 12 | juarez
# Processing Record 2 of Set 12 | brownwood
# Processing Record 3 of Set 12 | borba
# Processing Record 4 of Set 12 | flinders
# Processing Record 5 of Set 12 | sobolevo
# Processing Record 6 of Set 12 | kjollefjord
# Processing Record 7 of Set 12 | copiapo
# Processing Record 8 of Set 12 | aswan
# Processing Record 9 of Set 12 | champerico
# Processing Record 10 of Set 12 | turayf
# Processing Record 11 of Set 12 | langholm
# Processing Record 12 of Set 12 | plettenberg bay
# Processing Record 13 of Set 12 | sabha
# Processing Record 14 of Set 12 | shelburne
# Processing Record 15 of Set 12 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 16 of Set 12 | cleburne
# Processing Record 17 of Set 12 | minas de barroteran
# Processing Record 18 of Set 12 | ghanzi
# Processing Record 19 of Set 12 | uvalde
# Processing Record 20 of Set 12 | yar-sale
# Processing Record 21 of Set 12 | champagnole
# Processing Record 22 of Set 12 | marsa matruh
# Processing Record 23 of Set 12 | moa
# Processing Record 24 of Set 12 | nizhneudinsk
# Processing Record 25 of Set 12 | narnaul
# Processing Record 26 of Set 12 | zhuhai
# Processing Record 27 of Set 12 | manzil salim
# Processing Record 28 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 12 | kasongo
# Processing Record 30 of Set 12 | juba
# Processing Record 31 of Set 12 | arlit
# Processing Record 32 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 12 | aden
# Processing Record 34 of Set 12 | mortka
# Processing Record 35 of Set 12 | baena
# Processing Record 36 of Set 12 | lerik
# Processing Record 37 of Set 12 | korsor
# Processing Record 38 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 39 of Set 12 | gazli
# Processing Record 40 of Set 12 | barinas
# Processing Record 41 of Set 12 | methoni
# Processing Record 42 of Set 12 | sarahan
# Processing Record 43 of Set 12 | nouadhibou
# Processing Record 44 of Set 12 | methven
# Processing Record 45 of Set 12 | basco
# Processing Record 46 of Set 12 | newport
# Processing Record 47 of Set 12 | tambilil
# Processing Record 48 of Set 12 | isetskoye
# Processing Record 49 of Set 12 | narsaq
# Processing Record 50 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 13 | helong
# Processing Record 2 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 13 | rochester
# Processing Record 4 of Set 13 | tres rios
# Processing Record 5 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 13 | paamiut
# Processing Record 8 of Set 13 | orkney
# Processing Record 9 of Set 13 | whitehorse
# Processing Record 10 of Set 13 | svetlogorsk
# Processing Record 11 of Set 13 | bayan
# Processing Record 12 of Set 13 | sao gabriel da cachoeira
# Processing Record 13 of Set 13 | awjilah
# Processing Record 14 of Set 13 | tairua
# Processing Record 15 of Set 13 | payo
# Processing Record 16 of Set 13 | saint-joseph
# Processing Record 17 of Set 13 | fiumicino
# Processing Record 18 of Set 13 | hawalli
# Processing Record 19 of Set 13 | san juan
# Processing Record 20 of Set 13 | carinhanha
# Processing Record 21 of Set 13 | vanavara
# Processing Record 22 of Set 13 | encheng
# Processing Record 23 of Set 13 | arawa
# Processing Record 24 of Set 13 | raga
# Processing Record 25 of Set 13 | mozarlandia
# Processing Record 26 of Set 13 | moron
# Processing Record 27 of Set 13 | porbandar
# Processing Record 28 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 13 | moses lake
# Processing Record 30 of Set 13 | gainesville
# Processing Record 31 of Set 13 | sines
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | abu dhabi
# Processing Record 34 of Set 13 | conselheiro pena
# Processing Record 35 of Set 13 | obluche
# City not found. Skipping...
# Processing Record 36 of Set 13 | kudahuvadhoo
# Processing Record 37 of Set 13 | daboh
# Processing Record 38 of Set 13 | skarnes
# Processing Record 39 of Set 13 | palana
# Processing Record 40 of Set 13 | iraray
# Processing Record 41 of Set 13 | tera
# Processing Record 42 of Set 13 | anloga
# Processing Record 43 of Set 13 | road town
# Processing Record 44 of Set 13 | khandyga
# Processing Record 45 of Set 13 | darhan
# Processing Record 46 of Set 13 | tanggu
# Processing Record 47 of Set 13 | puebloviejo
# Processing Record 48 of Set 13 | gander
# Processing Record 49 of Set 13 | wawa
# Processing Record 50 of Set 13 | diffa
# Processing Record 1 of Set 14 | ahar
# Processing Record 2 of Set 14 | kahului
# Processing Record 3 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 4 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 14 | codrington
# Processing Record 6 of Set 14 | itororo
# Processing Record 7 of Set 14 | colesberg
# Processing Record 8 of Set 14 | kuryk
# Processing Record 9 of Set 14 | brownsville
# Processing Record 10 of Set 14 | trairi
# Processing Record 11 of Set 14 | mount gambier
# Processing Record 12 of Set 14 | zhangjiakou
# Processing Record 13 of Set 14 | takoradi
# Processing Record 14 of Set 14 | sedalia
# Processing Record 15 of Set 14 | kibala
# Processing Record 16 of Set 14 | henties bay
# Processing Record 17 of Set 14 | klaipeda
# Processing Record 18 of Set 14 | coquimbo
# Processing Record 19 of Set 14 | benalla
# Processing Record 20 of Set 14 | muravlenko
# Processing Record 21 of Set 14 | tete
# Processing Record 22 of Set 14 | turtas
# Processing Record 23 of Set 14 | inongo
# Processing Record 24 of Set 14 | oyon
# Processing Record 25 of Set 14 | le moule
# Processing Record 26 of Set 14 | keningau
# Processing Record 27 of Set 14 | state college
# Processing Record 28 of Set 14 | sayyan
# Processing Record 29 of Set 14 | severo-yeniseyskiy
# Processing Record 30 of Set 14 | dryden
# Processing Record 31 of Set 14 | mizdah
# Processing Record 32 of Set 14 | strezhevoy
# Processing Record 33 of Set 14 | chunskiy
# Processing Record 34 of Set 14 | kalmunai
# Processing Record 35 of Set 14 | zeya
# Processing Record 36 of Set 14 | gubskaya
# Processing Record 37 of Set 14 | tiznit
# Processing Record 38 of Set 14 | vila
# Processing Record 39 of Set 14 | namibe
# Processing Record 40 of Set 14 | sao jose de ribamar
# Processing Record 41 of Set 14 | half moon bay
# Processing Record 42 of Set 14 | palu
# Processing Record 43 of Set 14 | homer
# Processing Record 44 of Set 14 | tsogni
# Processing Record 45 of Set 14 | rybinsk
# Processing Record 46 of Set 14 | ketchikan
# Processing Record 47 of Set 14 | izvestkovyy
# Processing Record 48 of Set 14 | hualmay
# Processing Record 49 of Set 14 | rehoboth
# Processing Record 50 of Set 14 | sao felix do xingu
# Processing Record 1 of Set 15 | chernyshevskiy
# Processing Record 2 of Set 15 | hasaki
# Processing Record 3 of Set 15 | hami
# Processing Record 4 of Set 15 | melfort
# Processing Record 5 of Set 15 | ewo
# Processing Record 6 of Set 15 | nuuk
# Processing Record 7 of Set 15 | broome
# Processing Record 8 of Set 15 | sechura
# Processing Record 9 of Set 15 | athol
# Processing Record 10 of Set 15 | naze
# Processing Record 11 of Set 15 | salinas
# Processing Record 12 of Set 15 | nizhneangarsk
# Processing Record 13 of Set 15 | lubango
# Processing Record 14 of Set 15 | hajnowka
# Processing Record 15 of Set 15 | changuinola
# Processing Record 16 of Set 15 | skibbereen
# Processing Record 17 of Set 15 | abha
# Processing Record 18 of Set 15 | myanaung
# Processing Record 19 of Set 15 | guymon
# Processing Record 20 of Set 15 | ures
# Processing Record 21 of Set 15 | port-gentil
# Processing Record 22 of Set 15 | saint-denis
# Processing Record 23 of Set 15 | coruripe
# Processing Record 24 of Set 15 | nioro
# Processing Record 25 of Set 15 | batagay
# Processing Record 26 of Set 15 | ust-nera
# Processing Record 27 of Set 15 | ust-ishim
# Processing Record 28 of Set 15 | jha jha
# Processing Record 29 of Set 15 | los alamos
# Processing Record 30 of Set 15 | duluth
# Processing Record 31 of Set 15 | fomboni
# Processing Record 32 of Set 15 | torit
# Processing Record 33 of Set 15 | prince rupert
# Processing Record 34 of Set 15 | grootfontein
# Processing Record 35 of Set 15 | ubaira
# Processing Record 36 of Set 15 | cedar city
# Processing Record 37 of Set 15 | synya
# Processing Record 38 of Set 15 | kutum
# Processing Record 39 of Set 15 | hervey bay
# Processing Record 40 of Set 15 | loandjili
# Processing Record 41 of Set 15 | port hardy
# Processing Record 42 of Set 15 | dahanu
# Processing Record 43 of Set 15 | kiunga
# Processing Record 44 of Set 15 | manger
# Processing Record 45 of Set 15 | dungarvan
# Processing Record 46 of Set 15 | ambon
# Processing Record 47 of Set 15 | plaster rock
# Processing Record 48 of Set 15 | batemans bay
# Processing Record 49 of Set 15 | pisco
# Processing Record 50 of Set 15 | viedma
# Processing Record 1 of Set 16 | carmen
# Processing Record 2 of Set 16 | hyeres
# Processing Record 3 of Set 16 | avera
# Processing Record 4 of Set 16 | migori
# Processing Record 5 of Set 16 | karasjok
# Processing Record 6 of Set 16 | christchurch
# Processing Record 7 of Set 16 | quimper
# Processing Record 8 of Set 16 | lamin
# Processing Record 9 of Set 16 | umm ruwabah
# City not found. Skipping...
# Processing Record 10 of Set 16 | kapit
# Processing Record 11 of Set 16 | treinta y tres
# Processing Record 12 of Set 16 | dasoguz
# Processing Record 13 of Set 16 | dakar
# Processing Record 14 of Set 16 | ginir
# Processing Record 15 of Set 16 | elbistan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Puerto Ayora  -0.7393  -90.3518     72.79        75          95
# 1      Arraial Do Cabo -22.9661  -42.0278     68.95        60          56
# 2          Yellowknife  62.4560 -114.3525     64.92        59          40
# 3               Avarua -21.2078 -159.7750     75.25        64          20
# 4               Taltal -25.4000  -70.4833     57.04        85          41
# 5                Vaini -21.2000 -175.2000     77.16        83          40
# 6         Beringovskiy  63.0500  179.3167     34.23        99         100
# 7  Prachuap Khiri Khan  12.2167   99.7500     91.58        46         100
# 8              Rikitea -23.1203 -134.9692     75.25        75         100
# 9              Berasia  23.6333   77.4333     84.65        52          31
#
#    Wind Speed Country       Description
# 0        8.57      EC   overcast clouds
# 1        8.97      BR     broken clouds
# 2       12.66      CA  scattered clouds
# 3        9.22      CK        few clouds
# 4        1.32      CL  scattered clouds
# 5        9.22      TO  scattered clouds
# 6       14.58      RU     moderate rain
# 7       11.77      TH   overcast clouds
# 8       13.82      PF   overcast clouds
# 9       14.43      IN  scattered clouds

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Puerto Ayora      EC  -0.7393  -90.3518     72.79        75          95
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     68.95        60          56
# 2      Yellowknife      CA  62.4560 -114.3525     64.92        59          40
# 3           Avarua      CK -21.2078 -159.7750     75.25        64          20
# 4           Taltal      CL -25.4000  -70.4833     57.04        85          41
#
#    Wind Speed       Description
# 0        8.57   overcast clouds
# 1        8.97     broken clouds
# 2       12.66  scattered clouds
# 3        9.22        few clouds
# 4        1.32  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config_google import api_key

# Configure gmaps API key
gmaps.configure(api_key=api_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Puerto Ayora      EC  -0.7393  -90.3518     72.79        75
# 1        1  Arraial Do Cabo      BR -22.9661  -42.0278     68.95        60
# 2        2      Yellowknife      CA  62.4560 -114.3525     64.92        59
# 3        3           Avarua      CK -21.2078 -159.7750     75.25        64
# 4        4           Taltal      CL -25.4000  -70.4833     57.04        85
#
#    Cloudiness  Wind Speed       Description
# 0          95        8.57   overcast clouds
# 1          56        8.97     broken clouds
# 2          40       12.66  scattered clouds
# 3          20        9.22        few clouds
# 4          41        1.32  scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# Filter the dataset to find the cities that fit the criteria.
clean_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                       (city_data_df["Max Temp"] >= min_temp)]
clean_df.head(10)
# Out:
#     City_ID               City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3             Avarua      CK -21.2078 -159.7750     75.25        64
# 5         5              Vaini      TO -21.2000 -175.2000     77.16        83
# 8         8            Rikitea      PF -23.1203 -134.9692     75.25        75
# 9         9            Berasia      IN  23.6333   77.4333     84.65        52
# 11       11          Mount Isa      AU -20.7333  139.5000     80.37        12
# 14       14  Excelsior Springs      US  39.3392  -94.2261     76.08        75
# 15       15           Tateyama      JP  34.9833  139.8667     78.15        77
# 17       17              Fukue      JP  32.6881  128.8419     79.16        73
# 29       29          Namatanai      PG  -3.6667  152.4333     84.70        66
# 31       31         Port Blair      IN  11.6667   92.7500     83.52        79
#
#     Cloudiness  Wind Speed       Description
# 3           20        9.22        few clouds
# 5           40        9.22  scattered clouds
# 8          100       13.82   overcast clouds
# 9           31       14.43  scattered clouds
# 11          75        6.91     broken clouds
# 14           0        3.60         clear sky
# 15          97       12.64   overcast clouds
# 17          75        5.75     broken clouds
# 29          19        7.47        few clouds
# 31         100       20.71        light rain

# %%
# 4a. Determine if there are any empty rows.
clean_df.count()
# Out:
# City_ID        225
# City           225
# Country        225
# Lat            225
# Lng            225
# Max Temp       225
# Humidity       225
# Cloudiness     225
# Wind Speed     225
# Description    225
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                  City Country  Max Temp       Description      Lat       Lng  \
# 3              Avarua      CK     75.25        few clouds -21.2078 -159.7750
# 5               Vaini      TO     77.16  scattered clouds -21.2000 -175.2000
# 8             Rikitea      PF     75.25   overcast clouds -23.1203 -134.9692
# 9             Berasia      IN     84.65  scattered clouds  23.6333   77.4333
# 11          Mount Isa      AU     80.37     broken clouds -20.7333  139.5000
# 14  Excelsior Springs      US     76.08         clear sky  39.3392  -94.2261
# 15           Tateyama      JP     78.15   overcast clouds  34.9833  139.8667
# 17              Fukue      JP     79.16     broken clouds  32.6881  128.8419
# 29          Namatanai      PG     84.70        few clouds  -3.6667  152.4333
# 31         Port Blair      IN     83.52        light rain  11.6667   92.7500
#
#    Hotel Name
# 3
# 5
# 8
# 9
# 11
# 14
# 15
# 17
# 29
# 31

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": api_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]


    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"    

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()   
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.dropna(subset = ["Hotel Name"], inplace=True)
hotel_df.count()
# Out:
# City           225
# Country        225
# Max Temp       225
# Description    225
# Lat            225
# Lng            225
# Hotel Name     225
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
